# %%
import pandas as pd

df = pd.read_csv('/content/data-jumlah-vaksinasi-covid-19-tahap-3-tiga-menurut-kelurahan-di-provinsi-dki-jakarta-tahun-bulan-juli-2021.csv')
df
# Out:
#           tanggal  kode_kelurahan  ...    dosis jumlah_vaksin
# 0      2021-07-04      3171071002  ...  Dosis 1          3154
# 1      2021-07-04      3171041006  ...  Dosis 1          3042
# 2      2021-07-04      3171031006  ...  Dosis 1          3925
# 3      2021-07-04      3171051002  ...  Dosis 1          3674
# 4      2021-07-04      3171051001  ...  Dosis 1          3276
# ...           ...             ...  ...      ...           ...
# 14413  2021-07-31      3101011002  ...  Dosis 2           347
# 14414  2021-07-31      3101011001  ...  Dosis 2           136
# 14415  2021-07-31      3101021003  ...  Dosis 2            81
# 14416  2021-07-31      3101021002  ...  Dosis 2           385
# 14417  2021-07-31      3101021001  ...  Dosis 2            62
#
# [14418 rows x 8 columns]

# %%
df['penerima_vaksinasi'].value_counts()
# Out:
# Tahapan 3    14418
# Name: penerima_vaksinasi, dtype: int64

# %%
assert(df['kode_kelurahan'].nunique() == df['kelurahan'].nunique())

# %%
df_dropped = df.drop(['kode_kelurahan', 'penerima_vaksinasi'], axis=1)

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tanggal        14418 non-null  object
#  1   wilayah_kota   14418 non-null  object
#  2   kecamatan      14418 non-null  object
#  3   kelurahan      14418 non-null  object
#  4   dosis          14418 non-null  object
#  5   jumlah_vaksin  14418 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 676.0+ KB

# %%
df_dropped['dosis'].value_counts()
# Out:
# Dosis 1    7209
# Dosis 2    7209
# Name: dosis, dtype: int64

# %%
df_dropped['tanggal'] = pd.to_datetime(df_dropped['tanggal'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(data=df_dropped, x="tanggal", y="jumlah_vaksin")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 8))
sns.lineplot(data=df_dropped, x="tanggal", y="jumlah_vaksin", hue="wilayah_kota")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 8))
sns.lineplot(data=df_dropped, x="tanggal", y="jumlah_vaksin", hue="dosis")
plt.show()
