# %%
# !unzip -q -o /content/Pariwisata-20210926T081226Z-001.zip

# %%
import os, shutil
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
base_dir = 'Pariwisata'
csvList = sorted(os.listdir(base_dir))
for i, j in enumerate(csvList):
  # print(i.replace('.csv', '').replace('-', ' '))
  print(i, j)
# Out:
# 0 data-jumlah-hotel-berbintang-dan-non-bintang-jakarta-tahun-2020.csv
# 1 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-agustus-tahun-2020.csv
# 2 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-april-tahun-2020.csv
# 3 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-desember-tahun-2020.csv
# 4 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-februari-tahun-2020.csv
# 5 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-januari-tahun-2020.csv
# 6 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-juli-tahun-2020.csv
# 7 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-juni-tahun-2020.csv
# 8 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-maret-tahun-2020.csv
# 9 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-mei-tahun-2020.csv
# 10 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-november-tahun-2020.csv
# 11 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-oktober-tahun-2020.csv
# 12 data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta-bulan-september-tahun-2020.csv
# 13 data-jumlah-kunjungan-wisatawan-nusantara-bulan-agustus-tahun-2020.csv
# 14 data-jumlah-kunjungan-wisatawan-nusantara-bulan-april-tahun-2020.csv
# 15 data-jumlah-kunjungan-wisatawan-nusantara-bulan-desember-tahun-2020.csv
# 16 data-jumlah-kunjungan-wisatawan-nusantara-bulan-februari-tahun-2020.csv
# 17 data-jumlah-kunjungan-wisatawan-nusantara-bulan-januari-tahun-2020.csv
# 18 data-jumlah-kunjungan-wisatawan-nusantara-bulan-juni-tahun-2020.csv
# 19 data-jumlah-kunjungan-wisatawan-nusantara-bulan-maret-tahun-2020.csv
# 20 data-jumlah-kunjungan-wisatawan-nusantara-bulan-mei-tahun-2020.csv
# 21 data-jumlah-kunjungan-wisatawan-nusantara-bulan-november-tahun-2020.csv
# 22 data-jumlah-kunjungan-wisatawan-nusantara-bulan-oktober-tahun-2020.csv
# 23 data-jumlah-kunjungan-wisatawan-nusantara-bulan-september-tahun-2020.csv
# 24 data-jumlah-kunjungan-wisatawan-nusantara-juli-tahun-2020.csv
# 25 data-jumlah-peserta-pelatihan-profesi-kepariwisataan-di-provinsi-dki-jakarta-tahun-2019.csv
# 26 data-jumlah-statistik-wisata-di-provinsi-dki-jakarta-tahun-2017.csv
# 27 data-jumlah-statistik-wisata-di-provinsi-dki-jakarta-tahun-2018.csv
# 28 data-jumlah-statistik-wisata-di-provinsi-dki-jakarta-tahun-2019.csv
# 29 data-jumlah-usaha-jasa-pariwisata-tahun-2018.csv
# 30 data-jumlah-usaha-pariwisata-bidang-hiburan-dan-rekreasi-menurut-jenis-usaha-dan-kecamatan.csv
# 31 data-kategori-event-di-dki-jakarta-tahun-2016.csv
# 32 data-kategori-event-di-dki-jakarta-tahun-2017.csv
# 33 data-kategori-event-di-dki-jakarta-tahun-2018.csv
# 34 data-kategori-event-di-dki-jakarta-tahun-2019.csv
# 35 data-kunjungan-wisata-mancanegara-ke-indonesia-menurut-pintu-masuk-tahun-1995-2000.csv
# 36 data-kunjungan-wisatawan-mancanegara-ke-provinsi-dki-jakarta-bulan-januari-tahun-2020-melalui-2-pintu-masuk.csv
# 37 data-rata-rata-lama-menginap-wisatawan-nusantara-di-hotel-berbintang-provinsi-dki-jakarta-tahun-2016.csv
# 38 data-rata-rata-lama-menginap-wisatawan-nusantara-di-hotel-berbintang-provinsi-dki-jakarta-tahun-2017.csv
# 39 data-rata-rata-lama-menginap-wisatawan-nusantara-di-hotel-berbintang-provinsi-dki-jakarta-tahun-2018.csv

# %%
pd.read_csv(base_dir + '/' + csvList[1])
# Out:
#     tahun  bulan              destinasi_wisata  jumlah
# 0    2020      8       Taman Impian Jaya Ancol       0
# 1    2020      8    Taman Mini Indonesia Indah       0
# 2    2020      8      Taman Margasatwa Ragunan       0
# 3    2020      8              Monumen Nasional       0
# 4    2020      8               Museum Nasional       1
# 5    2020      8         Museum Satria Mandala       0
# 6    2020      8        Museum Sejarah Jakarta       0
# 7    2020      8                Museum Tekstil       0
# 8    2020      8                 Museum Bahari       5
# 9    2020      8  Museum Seni Rupa dan Keramik      10
# 10   2020      8                 Museum Wayang      28
# 11   2020      8                  Museum Joang       0
# 12   2020      8        Taman Arkeologi Onrust       0
# 13   2020      8        Pelabuhan Sunda Kelapa       0
# 14   2020      8              Kepulauan Seribu     209
# 15   2020      8              PBB Setu babakan       0
# 16   2020      8               Museum Prasasti       0
# 17   2020      8                   Planetarium       0
# 18   2020      8               Rumah si Pitung       0
# 19   2020      8              Kawasan Kota Tua     125

# %%
def concat_all_csv(files, sort_by = None, ascending=True):
  df_list = [pd.read_csv(i) for i in files]
  if sort_by is not None:
    return pd.concat(df_list).sort_values(sort_by, ascending=ascending)
  else:
    return pd.concat(df_list)

# %%
concat_all_csv([base_dir + '/' + i for i in csvList[1:13]], 'bulan').to_csv('data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta.csv', index=False)

# %%
destination_international = pd.read_csv('data-jumlah-kunjungan-wisatawan-mancanegara-ke-destinasi-wisata-di-provinsi-dki-jakarta.csv')

# %%
avg_international_tourist_destination = destination_international.groupby('destinasi_wisata').agg({'jumlah': 'mean'}).sort_values('jumlah', ascending=False)
avg_international_tourist_destination
# Out:
#                                    jumlah
# destinasi_wisata
# Kawasan Kota Tua              1315.583333
# Museum Nasional                449.750000
# Monumen Nasional               361.583333
# Museum Sejarah Jakarta         331.833333
# Kepulauan Seribu               301.166667
# Museum Wayang                  219.833333
# Taman Impian Jaya Ancol         89.666667
# Taman Margasatwa Ragunan        87.833333
# Museum Seni Rupa dan Keramik    58.500000
# Museum Bahari                   45.750000
# Museum Tekstil                  42.750000
# Pelabuhan Sunda Kelapa          15.000000
# Museum Prasasti                  6.666667
# Museum Joang                     2.750000
# PBB Setu babakan                 1.000000
# Taman Arkeologi Onrust           0.750000
# Rumah si Pitung                  0.083333
# Museum Satria Mandala            0.000000
# Planetarium                      0.000000
# Taman Mini Indonesia Indah       0.000000

# %%
concat_all_csv([base_dir + '/' + i for i in csvList[13:25]], 'bulan').to_csv('data-jumlah-kunjungan-wisatawan-nusantara-ke-destinasi-wisata-di-provinsi-dki-jakarta.csv', index=False)

# %%
destination_national = pd.read_csv('data-jumlah-kunjungan-wisatawan-nusantara-ke-destinasi-wisata-di-provinsi-dki-jakarta.csv')

# %%
avg_national_tourist_destination = destination_national.groupby('destinasi_wisata').agg({'jumlah': 'mean'}).sort_values('jumlah', ascending=False)
avg_national_tourist_destination
# Out:
#                                      jumlah
# destinasi_wisata
# Taman Impian Jaya Ancol       380244.333333
# Taman Mini Indonesia Indah    178114.333333
# Taman Margasatwa Ragunan      103394.750000
# Kawasan Kota Tua               99149.833333
# Monumen Nasional               53285.693750
# Kepulauan Seribu               20884.333333
# Museum Sejarah Jakarta         12777.000000
# PBB Setu babakan               12317.416667
# Museum Nasional                10680.333333
# Museum Wayang                   3884.000000
# Museum Seni Rupa dan Keramik    2485.500000
# Taman Arkeologi Onrust          2238.500000
# Planetarium                     1856.500000
# Pelabuhan Sunda Kelapa          1513.333333
# Rumah si Pitung                 1296.000000
# Museum Bahari                    760.416667
# Museum Tekstil                   661.416667
# Museum Prasasti                  329.833333
# Museum Joang 45                  302.636364
# Museum Joang                     267.000000
# Museum Satria Mandala            265.250000

# %%
len(avg_national_tourist_destination), len(avg_international_tourist_destination)
# Out:
# (21, 20)

# %%
tourist_destination = avg_national_tourist_destination.join(avg_international_tourist_destination, lsuffix='_national', rsuffix='_international', how='outer')
tourist_destination = tourist_destination.fillna(0)

# %%
tourist_destination.columns = ['avg_total_national', 'avg_total_international']
tourist_destination
# Out:
#                               avg_total_national  avg_total_international
# destinasi_wisata
# Kawasan Kota Tua                    99149.833333              1315.583333
# Kepulauan Seribu                    20884.333333               301.166667
# Monumen Nasional                    53285.693750               361.583333
# Museum Bahari                         760.416667                45.750000
# Museum Joang                          267.000000                 2.750000
# Museum Joang 45                       302.636364                 0.000000
# Museum Nasional                     10680.333333               449.750000
# Museum Prasasti                       329.833333                 6.666667
# Museum Satria Mandala                 265.250000                 0.000000
# Museum Sejarah Jakarta              12777.000000               331.833333
# Museum Seni Rupa dan Keramik         2485.500000                58.500000
# Museum Tekstil                        661.416667                42.750000
# Museum Wayang                        3884.000000               219.833333
# PBB Setu babakan                    12317.416667                 1.000000
# Pelabuhan Sunda Kelapa               1513.333333                15.000000
# Planetarium                          1856.500000                 0.000000
# Rumah si Pitung                      1296.000000                 0.083333
# Taman Arkeologi Onrust               2238.500000                 0.750000
# Taman Impian Jaya Ancol            380244.333333                89.666667
# Taman Margasatwa Ragunan           103394.750000                87.833333
# Taman Mini Indonesia Indah         178114.333333                 0.000000

# %%
tourist_destination['avg_total_international_percentage'] = tourist_destination['avg_total_international'] / tourist_destination['avg_total_international'].sum() * 100
tourist_destination['avg_total_national_percentage'] = tourist_destination['avg_total_national'] / tourist_destination['avg_total_national'].sum() * 100

# %%
tourist_destination
# Out:
#                               avg_total_national  ...  avg_total_national_percentage
# destinasi_wisata                                  ...
# Kawasan Kota Tua                    99149.833333  ...                      11.181786
# Kepulauan Seribu                    20884.333333  ...                       2.355265
# Monumen Nasional                    53285.693750  ...                       6.009382
# Museum Bahari                         760.416667  ...                       0.085757
# Museum Joang                          267.000000  ...                       0.030111
# Museum Joang 45                       302.636364  ...                       0.034130
# Museum Nasional                     10680.333333  ...                       1.204492
# Museum Prasasti                       329.833333  ...                       0.037197
# Museum Satria Mandala                 265.250000  ...                       0.029914
# Museum Sejarah Jakarta              12777.000000  ...                       1.440947
# Museum Seni Rupa dan Keramik         2485.500000  ...                       0.280306
# Museum Tekstil                        661.416667  ...                       0.074592
# Museum Wayang                        3884.000000  ...                       0.438024
# PBB Setu babakan                    12317.416667  ...                       1.389117
# Pelabuhan Sunda Kelapa               1513.333333  ...                       0.170669
# Planetarium                          1856.500000  ...                       0.209370
# Rumah si Pitung                      1296.000000  ...                       0.146159
# Taman Arkeologi Onrust               2238.500000  ...                       0.252451
# Taman Impian Jaya Ancol            380244.333333  ...                      42.882680
# Taman Margasatwa Ragunan           103394.750000  ...                      11.660513
# Taman Mini Indonesia Indah         178114.333333  ...                      20.087137
#
# [21 rows x 4 columns]

# %%
idx = np.arange(len(tourist_destination)) * 2
plt.figure(figsize=(20, 12))
plt.bar(idx - 0.25, tourist_destination['avg_total_national_percentage'], color='blue', width=0.5)
plt.bar(idx + 0.25, tourist_destination['avg_total_international_percentage'], color='red', width=0.5)
plt.xticks(idx, tourist_destination.index, rotation=45)
plt.title('national vs international tourist destination')
plt.xlabel('destination')
plt.ylabel('percentage of tourist visiting', rotation = 90)
plt.show()
