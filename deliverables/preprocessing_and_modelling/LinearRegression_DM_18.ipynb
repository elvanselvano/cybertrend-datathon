# %%
# !pip install geopandas
# !pip install unrar
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 5.1 MB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp37-cp37m-manylinux1_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 39 kB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 56.2 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.7.1)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2.8.2)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.9.0 munch-2.5.0 pyproj-3.2.1
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4

# %%
# !unrar x /content/Indonesia_Kab_Kota.rar -y
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/Indonesia_Kab_Kota.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/Tingkat Penghunian Kamar pada Hotel Bintang 2020.xlsx', skiprows=2, skipfooter=2)
df = df.dropna().drop('Tahunan', axis=1)

# %%
column_names = df.columns.to_list()
column_names[0] = 'wilayah'
df.columns = column_names
df
# Out:
#                  wilayah  Januari  Februari  ...  Oktober  November  Desember
# 0                   ACEH    35.36     39.33  ...    30.11     37.71     31.76
# 1         SUMATERA UTARA    48.06     45.24  ...    36.09     34.41     41.02
# 2         SUMATERA BARAT    44.21     46.55  ...    39.45     47.49     53.44
# 3                   RIAU    42.49     44.09  ...    36.16     42.92     36.39
# 4                  JAMBI    41.66     42.69  ...    38.88     40.93     40.74
# 5       SUMATERA SELATAN    48.11     53.22  ...    47.55     48.92     53.83
# 6               BENGKULU    43.11     61.85  ...    49.88     45.45     45.00
# 7                LAMPUNG    57.88     57.38  ...    54.28     59.14     59.32
# 8   KEP. BANGKA BELITUNG    27.35     30.88  ...    24.63     28.42     28.79
# 9              KEP. RIAU    46.49     35.58  ...    21.59     24.64     27.41
# 10           DKI JAKARTA    51.37     54.28  ...    44.33     45.63     45.40
# 11            JAWA BARAT    47.06     50.15  ...    43.57     48.89     45.22
# 12           JAWA TENGAH    41.51     46.36  ...    35.05     37.89     35.69
# 13         DI YOGYAKARTA    52.93     56.32  ...    45.52     44.99     45.31
# 14            JAWA TIMUR    48.69     52.65  ...    42.09     45.47     47.77
# 15                BANTEN    49.05     51.14  ...    38.28     42.61     38.51
# 16                  BALI    59.29     45.98  ...     9.53      9.32     19.00
# 17   NUSA TENGGARA BARAT    38.93     36.70  ...    34.49     37.30     43.90
# 18   NUSA TENGGARA TIMUR    39.26     38.50  ...    36.53     42.51     38.00
# 19      KALIMANTAN BARAT    46.62     49.41  ...    37.95     42.03     38.39
# 20     KALIMANTAN TENGAH    39.74     48.28  ...    53.47     58.21     48.27
# 21    KALIMANTAN SELATAN    37.20     48.35  ...    49.64     52.74     51.21
# 22      KALIMANTAN TIMUR    50.84     61.25  ...    51.34     54.76     59.78
# 23      KALIMANTAN UTARA    33.11     40.95  ...    45.51     45.13     39.34
# 24        SULAWESI UTARA    59.10     44.01  ...    52.25     51.48     42.39
# 25       SULAWESI TENGAH    47.94     48.35  ...    40.30     50.84     49.69
# 26      SULAWESI SELATAN    48.14     49.26  ...    34.27     42.56     54.82
# 27     SULAWESI TENGGARA    39.18     54.32  ...    35.91     40.29     43.63
# 28             GORONTALO    30.50     44.86  ...    41.01     58.80     56.90
# 29        SULAWESI BARAT    42.59     49.72  ...    36.20     43.08     49.54
# 30                MALUKU    31.79     38.16  ...    46.90     45.18     43.29
# 31          MALUKU UTARA    56.74     41.15  ...    37.03     39.47     43.19
# 32           PAPUA BARAT    50.40     57.41  ...    38.17     53.51     58.51
# 33                 PAPUA    41.14     51.43  ...    46.58     55.22     36.25
# 34             INDONESIA    49.17     49.22  ...    37.48     40.14     40.79
#
# [35 rows x 13 columns]

# %%
df['wilayah'] = df['wilayah'].apply(str.lower)
df['year_avg'] = df[column_names[1:]].mean(axis=1)
df
# Out:
#                  wilayah  Januari  Februari  ...  November  Desember   year_avg
# 0                   aceh    35.36     39.33  ...     37.71     31.76  25.165833
# 1         sumatera utara    48.06     45.24  ...     34.41     41.02  30.778333
# 2         sumatera barat    44.21     46.55  ...     47.49     53.44  34.007500
# 3                   riau    42.49     44.09  ...     42.92     36.39  32.047500
# 4                  jambi    41.66     42.69  ...     40.93     40.74  34.060000
# 5       sumatera selatan    48.11     53.22  ...     48.92     53.83  40.533333
# 6               bengkulu    43.11     61.85  ...     45.45     45.00  37.960000
# 7                lampung    57.88     57.38  ...     59.14     59.32  43.749167
# 8   kep. bangka belitung    27.35     30.88  ...     28.42     28.79  22.742500
# 9              kep. riau    46.49     35.58  ...     24.64     27.41  22.757500
# 10           dki jakarta    51.37     54.28  ...     45.63     45.40  38.728333
# 11            jawa barat    47.06     50.15  ...     48.89     45.22  35.220833
# 12           jawa tengah    41.51     46.36  ...     37.89     35.69  28.838333
# 13         di yogyakarta    52.93     56.32  ...     44.99     45.31  34.155833
# 14            jawa timur    48.69     52.65  ...     45.47     47.77  35.294167
# 15                banten    49.05     51.14  ...     42.61     38.51  34.624167
# 16                  bali    59.29     45.98  ...      9.32     19.00  15.618333
# 17   nusa tenggara barat    38.93     36.70  ...     37.30     43.90  27.574167
# 18   nusa tenggara timur    39.26     38.50  ...     42.51     38.00  29.635833
# 19      kalimantan barat    46.62     49.41  ...     42.03     38.39  32.845000
# 20     kalimantan tengah    39.74     48.28  ...     58.21     48.27  37.905833
# 21    kalimantan selatan    37.20     48.35  ...     52.74     51.21  38.120833
# 22      kalimantan timur    50.84     61.25  ...     54.76     59.78  44.503333
# 23      kalimantan utara    33.11     40.95  ...     45.13     39.34  34.181667
# 24        sulawesi utara    59.10     44.01  ...     51.48     42.39  37.614167
# 25       sulawesi tengah    47.94     48.35  ...     50.84     49.69  36.407500
# 26      sulawesi selatan    48.14     49.26  ...     42.56     54.82  38.173333
# 27     sulawesi tenggara    39.18     54.32  ...     40.29     43.63  30.670833
# 28             gorontalo    30.50     44.86  ...     58.80     56.90  32.827500
# 29        sulawesi barat    42.59     49.72  ...     43.08     49.54  30.967500
# 30                maluku    31.79     38.16  ...     45.18     43.29  35.500833
# 31          maluku utara    56.74     41.15  ...     39.47     43.19  28.535833
# 32           papua barat    50.40     57.41  ...     53.51     58.51  37.937500
# 33                 papua    41.14     51.43  ...     55.22     36.25  34.350833
# 34             indonesia    49.17     49.22  ...     40.14     40.79  32.415000
#
# [35 rows x 14 columns]

# %%
geo_df = gpd.read_file('/content/SHP/Indo_Kab_Kot.shp')
geo_df['PROVINSI'] = geo_df['PROVINSI'].apply(str.lower)

# %%
joined_df = df.merge(geo_df, left_on='wilayah', right_on='PROVINSI')
joined_df
# Out:
#     wilayah  ...                                           geometry
# 0      aceh  ...  MULTIPOLYGON Z (((96.66509 2.12018 0.00000, 96...
# 1      aceh  ...  MULTIPOLYGON Z (((97.95406 2.57693 0.00000, 97...
# 2      aceh  ...  MULTIPOLYGON Z (((97.39711 2.03835 0.00000, 97...
# 3      aceh  ...  MULTIPOLYGON Z (((97.59461 2.80777 0.00000, 97...
# 4      aceh  ...  POLYGON Z ((97.82461 3.74953 0.00000, 97.82177...
# ..      ...  ...                                                ...
# 495   papua  ...  POLYGON Z ((137.40540 -2.98613 0.00000, 137.40...
# 496   papua  ...  POLYGON Z ((136.09374 -3.75452 0.00000, 136.10...
# 497   papua  ...  POLYGON Z ((136.30963 -2.91129 0.00000, 136.31...
# 498   papua  ...  POLYGON Z ((136.48040 -4.01226 0.00000, 136.49...
# 499   papua  ...  MULTIPOLYGON Z (((140.70816 -2.59714 0.00000, ...
#
# [500 rows x 19 columns]

# %%
joined_geo_df = gpd.GeoDataFrame(joined_df, geometry='geometry')

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 12))
joined_geo_df.plot('year_avg', ax=ax, cmap='coolwarm', legend=True, legend_kwds={'shrink': 0.3})
fig.suptitle('Indonesia star hotel occupancy rate 2020', fontsize=20)
ax.axis('off')
plt.subplots_adjust(top=1.3)
plt.show()

# %%
df = pd.read_excel('/content/Tingkat Penghunian Kamar pada Hotel Bintang 2021.xlsx', skiprows=2, skipfooter=2)
df = df.dropna().drop(['Tahunan', 'Agustus', 'September', 'Oktober', 'November', 'Desember'], axis=1)
df
# Out:
#               Unnamed: 0  Januari  Februari  Maret  April    Mei   Juni   Juli
# 0                   ACEH    20.13     17.65  33.42  26.45  26.08  28.09  26.88
# 1         SUMATERA UTARA    37.63     36.58  37.67  36.96  33.91  39.10  29.87
# 2         SUMATERA BARAT    37.27     36.04  42.02  35.23  32.21  49.72  28.13
# 3                   RIAU    36.69     38.16  38.69  34.53  31.54  33.40  34.42
# 4                  JAMBI    26.50     38.42  41.57  38.96  33.67  45.13  28.78
# 5       SUMATERA SELATAN    45.85     46.11  48.24  44.41  43.55  53.42  41.70
# 6               BENGKULU    31.96     37.65  36.73  33.37  33.25  45.54  24.61
# 7                LAMPUNG    37.63     40.52  43.98  40.78  34.29  49.65  24.65
# 8   KEP. BANGKA BELITUNG    18.70     15.06  20.98  17.44  15.24  23.92  15.75
# 9              KEP. RIAU    24.41     27.99  27.01  20.69  20.92  23.03  19.10
# 10           DKI JAKARTA    41.12     41.53  45.11  46.59  45.23  51.90  31.72
# 11            JAWA BARAT    29.16     37.15  40.37  38.40  35.72  38.19  19.48
# 12           JAWA TENGAH    24.73     26.64  33.27  32.18  28.11  31.95  15.22
# 13         DI YOGYAKARTA    24.91     26.87  40.42  36.78  32.27  45.73  13.32
# 14            JAWA TIMUR    38.63     36.39  40.20  38.88  35.00  44.16  26.25
# 15                BANTEN    37.06     39.19  41.30  41.83  34.10  38.64  24.59
# 16                  BALI    11.15      8.99  10.24  10.09  10.35  16.68   5.23
# 17   NUSA TENGGARA BARAT    20.17     31.20  36.45  27.04  28.52  39.92  26.25
# 18   NUSA TENGGARA TIMUR    22.51     18.40  27.40  38.67  30.00  41.39  20.35
# 19      KALIMANTAN BARAT    25.84     34.93  40.97  41.16  38.29  39.86  29.58
# 20     KALIMANTAN TENGAH    32.54     42.05  46.71  39.86  36.23  47.18  27.80
# 21    KALIMANTAN SELATAN    43.30     38.01  38.38  34.20  31.78  41.45  34.28
# 22      KALIMANTAN TIMUR    42.98     43.82  49.38  47.43  46.77  57.67  39.04
# 32           papua barat    39.40     44.58  ...  49.60  28.81         41.392857
# 33                 papua    35.00     32.64  ...  44.93  40.16         38.371429
# 34             indonesia    30.35     32.40  ...  38.55  22.38         32.335714
#
# [35 rows x 9 columns]

# %%
joined_df = df.merge(geo_df, left_on='wilayah', right_on='PROVINSI')
joined_df
# Out:
#     wilayah  ...                                           geometry
# 0      aceh  ...  MULTIPOLYGON Z (((96.66509 2.12018 0.00000, 96...
# 1      aceh  ...  MULTIPOLYGON Z (((97.95406 2.57693 0.00000, 97...
# 2      aceh  ...  MULTIPOLYGON Z (((97.39711 2.03835 0.00000, 97...
# 3      aceh  ...  MULTIPOLYGON Z (((97.59461 2.80777 0.00000, 97...
# 4      aceh  ...  POLYGON Z ((97.82461 3.74953 0.00000, 97.82177...
# ..      ...  ...                                                ...
# 495   papua  ...  POLYGON Z ((137.40540 -2.98613 0.00000, 137.40...
# 496   papua  ...  POLYGON Z ((136.09374 -3.75452 0.00000, 136.10...
# 497   papua  ...  POLYGON Z ((136.30963 -2.91129 0.00000, 136.31...
# 498   papua  ...  POLYGON Z ((136.48040 -4.01226 0.00000, 136.49...
# 499   papua  ...  MULTIPOLYGON Z (((140.70816 -2.59714 0.00000, ...
#
# [500 rows x 14 columns]

# %%
joined_geo_df = gpd.GeoDataFrame(joined_df, geometry='geometry')
fig, ax = plt.subplots(1, 1, figsize = (20, 12))
joined_geo_df.plot('year_avg_to_date', ax=ax, cmap='coolwarm', legend=True, legend_kwds={'shrink': 0.3})
fig.suptitle('Indonesia star hotel occupancy rate 2021 (to date)', fontsize=20)
ax.axis('off')
plt.subplots_adjust(top=1.3)
plt.show()

# %%
df = pd.read_excel('/content/Tingkat Penghunian Kamar pada Hotel Bintang 2019.xlsx', skiprows=2)
df = df.dropna().drop(['Tahunan'], axis=1)
column_names = df.columns.to_list()
column_names[0] = 'wilayah'
df.columns = column_names
df['wilayah'] = df['wilayah'].apply(str.lower)
df['year_avg_to_date'] = df[column_names[1:]].mean(axis=1)
joined_df = df.merge(geo_df, left_on='wilayah', right_on='PROVINSI')
joined_geo_df = gpd.GeoDataFrame(joined_df, geometry='geometry')
fig, ax = plt.subplots(1, 1, figsize = (20, 12))
joined_geo_df.plot('year_avg_to_date', ax=ax, cmap='coolwarm', legend=True, legend_kwds={'shrink': 0.3})
fig.suptitle('Indonesia star hotel occupancy rate 2019', fontsize=20)
ax.axis('off')
plt.subplots_adjust(top=1.3)
plt.show()

# %%
df = pd.read_excel('/content/Tingkat Penghunian Kamar pada Hotel Bintang 2018.xlsx', skiprows=2)
df = df.dropna().drop(['Tahunan'], axis=1)
column_names = df.columns.to_list()
column_names[0] = 'wilayah'
df.columns = column_names
df['wilayah'] = df['wilayah'].apply(str.lower)
df['year_avg_to_date'] = df[column_names[1:]].mean(axis=1)
joined_df = df.merge(geo_df, left_on='wilayah', right_on='PROVINSI')
joined_geo_df = gpd.GeoDataFrame(joined_df, geometry='geometry')
fig, ax = plt.subplots(1, 1, figsize = (20, 12))
joined_geo_df.plot('year_avg_to_date', ax=ax, cmap='coolwarm', legend=True, legend_kwds={'shrink': 0.3})
fig.suptitle('Indonesia star hotel occupancy rate 2018', fontsize=20)
ax.axis('off')
plt.subplots_adjust(top=1.3)
plt.show()
